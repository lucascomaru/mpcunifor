# %%
import pandas as pd

alunos = pd.read_excel(r'C:\Users\lucas\OneDrive\Área de Trabalho\Mat - Unifor\Base de Alunos.xlsx')
dengue = pd.read_excel(r'C:\Users\lucas\OneDrive\Área de Trabalho\Mat - Unifor\Base de Dengue.xlsx')
onibus = pd.read_excel(r'C:\Users\lucas\OneDrive\Área de Trabalho\Mat - Unifor\Base de Onibus.xlsx')
display(alunos)
display(dengue)
display(onibus)
# Out:
#       ID                      Nome                 Nome do Pai  \
# 0      0      ANTONIO SILVA NONATO     ANTONIO OLIVEIRA NONATO
# 1      1  RAFAEL OLIVEIRA FERREIRA  FRANCISCO CANDIDO FERREIRA
# 2      2   VALDILENE SOCORRO SILVA                    JOAO A S
# 3      3      CARLA GONDIM ELIESIO       RODRIGO BRITO ELIESIO
# 4      4    ZUALA RODQIGUES ZENDES        RAIMUNDO VALE MENDES
# ..   ...                       ...                         ...
# 261  261                   GERLANA         FLATIO SIUVA PAIXAO
# 262  262         BRENA CARMO BRAGA       VICENTE DASILVA BRAGA
# 263  263         MARIA COSTA SILVA                   FRANCISCO
# 264  264                   LUIGR Z                   FRANCISCO
# 265  265    MARIA OLIVEIRA PEREIRA        MANOEL SILVA PEREIRA
#
#                     Nome da Mãe Sexo   Data de Nascimento
# 0             MARIA SILVA EUNCE    m  2000-06-26 00:00:00
# 1                         MARIA    m          29/16/1994
# ...
